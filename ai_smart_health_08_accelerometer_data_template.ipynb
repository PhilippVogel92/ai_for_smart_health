# %% [markdown]
# # Tutorial PAMAP2 with mcfly

# %% [markdown]
# The goal of this tutorial is to get you familiar with training Neural Networks for time series. At the end of the tutorial, you will have compared several Neural Network architectures you know how to train the best performing network. To quickly be able to compare several different deep learning architectures, we will use the Python libraray `mcfly`.
#
# As an example dataset we use the publicly available [PAMAP2 dataset](https://archive.ics.uci.edu/ml/datasets/PAMAP2+Physical+Activity+Monitoring). It contains time series data from movement sensors worn by nine individuals. The data is labelled with the activity types that these individuals did and the aim is to train and evaluate a *classifier*.
#
# Before you can start, please make sure you install mcfly (see the [mcfly installation page](https://github.com/NLeSC/mcfly)).

# %% [markdown]
# ## Import required Python modules

# %%
#!pip install mcfly
# Out:
# Collecting mcfly
#   Downloading mcfly-4.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from mcfly) (1.23.4)
# Requirement already satisfied: h5py in c:\users\phili\appdata\roaming\python\python39\site-packages (from mcfly) (3.7.0)
# Requirement already satisfied: scikit-learn>=0.15.0 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from mcfly) (1.1.2)
# Requirement already satisfied: tensorflow>=2.0.0 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from mcfly) (2.11.0)
# Requirement already satisfied: scipy>=0.11 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from mcfly) (1.10.1)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from scikit-learn>=0.15.0->mcfly) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from scikit-learn>=0.15.0->mcfly) (3.1.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\phili\appdata\roaming\python\python39\site-packages (from tensorflow>=2.0.0->mcfly) (2.11.0)
# Requirement already satisfied: packaging in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (21.3)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\phili\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (2.11.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (1.16.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (0.2.0)
# Requirement already satisfied: setuptools in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (65.5.0)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (1.14.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (14.0.6)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (0.27.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (22.10.26)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (2.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (4.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\phili\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (1.6.3)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (2.11.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (1.50.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\phili\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (1.3.0)
# Collecting protobuf<3.20,>=3.9.2
#   Using cached protobuf-3.19.6-cp39-cp39-win_amd64.whl (895 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (2.11.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (2.14.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\phili\appdata\roaming\python\python39\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (2.28.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (2.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (3.4.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from packaging->tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (5.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (3.9.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\phili\anaconda3\envs\chatbots\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0.0->mcfly) (3.2.2)
# Installing collected packages: protobuf, gast, mcfly
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
# Successfully installed gast-0.4.0 mcfly-4.0.0 protobuf-3.19.6
# WARNING: Ignoring invalid distribution -cipy (c:\users\phili\anaconda3\envs\chatbots\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\phili\anaconda3\envs\chatbots\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\phili\anaconda3\envs\chatbots\lib\site-packages)
#     WARNING: Ignoring invalid distribution -cipy (c:\users\phili\anaconda3\envs\chatbots\lib\site-packages)
#     WARNING: Ignoring invalid distribution -cipy (c:\users\phili\anaconda3\envs\chatbots\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\phili\anaconda3\envs\chatbots\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\phili\anaconda3\envs\chatbots\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\phili\anaconda3\envs\chatbots\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\phili\anaconda3\envs\chatbots\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\phili\anaconda3\envs\chatbots\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\phili\anaconda3\envs\chatbots\lib\site-packages)

# %%
import sys
import os
import numpy as np
import pandas as pd
# mcfly
import mcfly
import tensorflow as tf
np.random.seed(2)
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
sys.path.insert(0, os.path.abspath('../..'))
import pamap2_utils as utils

# %% [markdown]
# ## Download data pre-procesed data

# %% [markdown]
# We have created a function for you to fetch the preprocessed data from https://zenodo.org/record/834467. Please specify the `directory_to_extract_to` in the code below and then execute the cell. This will download the preprocessed data into the directory in the `data` subdirectory. The output of the function is the path where the preprocessed data was stored.

# %%
# Specify in which directory you want to store the data:
directory_to_extract_to = 'data/'

# %%
data_path = utils.download_preprocessed_data(directory_to_extract_to)
# Out:
# Downloading data...
# Extracting data...
# Done

# %% [markdown]
# ## A bit about the data

# %% [markdown]
# The [PAMAP2 dataset](https://archive.ics.uci.edu/ml/datasets/PAMAP2+Physical+Activity+Monitoring) contains data from three movement sensors worn on the hand, ankle and chest by nine test subjects. These subjects performed a protocol of several activities.
#
# Each sensor has three channels (acceleration on x, y and z axes). This gives us, for each time step, 9 values. The data is recorded on 100 Hz.
#
# The preprocessed data is split into smaller segments with a window of 512 time steps, corresponding to 5.12 seconds. We only include segments that completely fall into one activity period: the activity is the *label* of the segment.
#
# The goal of classification is to assign an activity label to an previously unseen segment.

# %% [markdown]
# ## Load the pre-processed data

# %% [markdown]
# Load the preprocessed data as stored in Numpy-files. Please note that the data has already been split up in a training (\~91%), validation (\~1%), and test (\~8%) subsets. It is common practice to call the input data X and the labels y.

# %%
X_train, y_train_binary, X_val, y_val_binary, X_test, y_test_binary, labels = utils.load_data(data_path)

# %% [markdown]
# Data X and labels y are of type Numpy array. In the cell below we inspect the shape of the data. As you can see the shape of X is expressed as a Python tuple containing: the number of samples, length of the time series, and the number of channels for each sample. Similarly, the shape of y is represents the number of samples and the number of classes (unique labels). Note that y has the format of a binary array where only the correct class for each sample is assigned a 1. This is called one-hot-encoding.

# %%
print('X training shape:', X_train.shape)
print('y training shape:', y_train_binary.shape)
print('y validation shape:', y_val_binary.shape)
print('y test shape:', y_test_binary.shape)
# Out:
# X training shape: (11397, 512, 9)
# y training shape: (11397, 7)
# y validation shape: (100, 7)
# y test shape: (1000, 7)

# %% [markdown]
# The data is split between train test and validation.

# %% [markdown]
# Let's have a look at the distribution of the labels:

# %%
from matplotlib import pyplot as plt
plt.style.use('ggplot')

data_labels = ["wrist_x", "wrist_y", "wrist_z",
               "chest_x", "chest_y", "chest_z",
               "ankle_x", "ankle_y", "ankle_z"]

# Get the viridis colormap
cmap = plt.cm.get_cmap('viridis', len(data_labels))

fig, ax = plt.subplots(1, 1, figsize=(12, 5))

for i, label in enumerate(data_labels):
    ax.plot(np.array(X_train[5, :, i]), color=cmap(i), label=label)

ax.set_xlabel('time points')
ax.legend()
plt.show()

# %%
print(y_train_binary[5])
labels
# Out:
# [0. 0. 0. 0. 1. 0. 0.]
# ['lying',
#  'sitting',
#  'standing',
#  'walking',
#  'cycling',
#  'vaccuum_cleaning',
#  'ironing']

# %%
frequencies = y_train_binary.mean(axis=0)
# inspect frequencies
frequencies_df = pd.DataFrame({'label': labels, 'frequency': frequencies})
frequencies_df
# Out:
#               label  frequency
# 0             lying   0.136615
# 1           sitting   0.130736
# 2          standing   0.136703
# 3           walking   0.176625
# 4           cycling   0.118540
# 5  vaccuum_cleaning   0.125208
# 6           ironing   0.175573

# %% [markdown]
# ### *Question 1: How many channels does this dataset have?*
# ### *Question 2: What is the least common activity label in this dataset?*

# %% [markdown]
# ## Generate models

# %% [markdown]
# First step in the development of any deep learning model is to create a model architecture. As we do not know what architecture is best for our data we will create a set of random models to investigate which architecture is most suitable for our data and classification task. This process, creating random models, checking how good they are and then selecting the best one is called a 'random search'. A random search is considered to be the most robust approach to finding a good model. You will need to specificy how many models you want to create with argument 'number_of_models'. See for a full overview of the optional arguments the function documentation of modelgen.generate_models by running `modelgen.generate_models?`.
#
# ##### What number of models to select?
# This number differs per dataset. More models will give better results but it will take longer to evaluate them. For the purpose of this tutorial we recommend trying only 2 models to begin with. If you have enough time you can try a larger number of models, e.g. 10 or 20 models. Because mcfly uses random search, you will get better results when using more models.

# %%
num_classes = len(labels)
metric = 'accuracy'
models = mcfly.modelgen.generate_models(X_train.shape,
                                        number_of_output_dimensions=num_classes,
                                        number_of_models = 4,
                                        metrics=[metric]
                                       )
# Out:
# c:\Users\Phili\anaconda3\envs\chatbots\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %% [markdown]
# # Inspect the models
# We can have a look at the models that were generated. The layers are shown as table rows. Most common layer types are 'Convolution' and 'LSTM' and 'Dense'. For more information see the [mcfly user manual](https://github.com/NLeSC/mcfly/wiki/User-manual) and the [tutorial cheat sheet](https://github.com/NLeSC/mcfly-tutorial/blob/master/cheatsheet.md). The summary also shows the data shape of each layer output and the number of parameters that are trained within this layer.

# %%
models_to_print = range(len(models))
for i, item in enumerate(models):
    if i in models_to_print:
        model, params, model_types = item
        print("-------------------------------------------------------------------------------------------------------")
        print("Model " + str(i), '\n')          
        print("Model type:", model_types, '\n')        
        print("Hyperparameters:")
        print(params)
        print(" ")
        print("Model description:")
        model.summary()        
        print(" ")
# Out:
# -------------------------------------------------------------------------------------------------------
# Model 0
#
# Model type: ResNet
#
# Hyperparameters:
# {'learning_rate': 0.0022439468517196116, 'regularization_rate': 0.004943480463153602, 'network_depth': 2, 'min_filters_number': 39, 'max_kernel_size': 10}
#
# Model description:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 9)]     0           []
#
#  batch_normalization (BatchNorm  (None, 512, 9)      36          ['input_1[0][0]']
#  alization)
#
#  conv1d (Conv1D)                (None, 512, 39)      3549        ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 512, 39)     156         ['conv1d[0][0]']
#  rmalization)
#
#  re_lu (ReLU)                   (None, 512, 39)      0           ['batch_normalization_1[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 512, 39)      15249       ['re_lu[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 512, 39)     156         ['conv1d_1[0][0]']
#  rmalization)
#
#  re_lu_1 (ReLU)                 (None, 512, 39)      0           ['batch_normalization_2[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 512, 39)      15249       ['re_lu_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 512, 39)     156         ['conv1d_2[0][0]']
#  rmalization)
#
#  re_lu_2 (ReLU)                 (None, 512, 39)      0           ['batch_normalization_3[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 512, 39)      1560        ['re_lu_2[0][0]']
#
#  add (Add)                      (None, 512, 39)      0           ['re_lu_2[0][0]',
#                                                                   'conv1d_3[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 512, 54)      14796       ['add[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 512, 54)     216         ['conv1d_4[0][0]']
#  rmalization)
#
#  re_lu_3 (ReLU)                 (None, 512, 54)      0           ['batch_normalization_4[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 512, 54)      20466       ['re_lu_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 512, 54)     216         ['conv1d_5[0][0]']
#  rmalization)
#
#  re_lu_4 (ReLU)                 (None, 512, 54)      0           ['batch_normalization_5[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 512, 54)      20466       ['re_lu_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 512, 54)     216         ['conv1d_6[0][0]']
#  rmalization)
#
#  re_lu_5 (ReLU)                 (None, 512, 54)      0           ['batch_normalization_6[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 512, 54)      2970        ['re_lu_5[0][0]']
#
#  add_1 (Add)                    (None, 512, 54)      0           ['re_lu_5[0][0]',
#                                                                   'conv1d_7[0][0]']
#
#  global_average_pooling1d (Glob  (None, 54)          0           ['add_1[0][0]']
#  alAveragePooling1D)
#
#  dense (Dense)                  (None, 7)            385         ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  activation (Activation)        (None, 7)            0           ['dense[0][0]']
#
# ==================================================================================================
# Total params: 95,842
# Trainable params: 95,266
# Non-trainable params: 576
# __________________________________________________________________________________________________
#
# -------------------------------------------------------------------------------------------------------
# Model 1
#
# Model type: InceptionTime
#
# Hyperparameters:
# {'learning_rate': 0.03441279764432193, 'regularization_rate': 0.0008005932532411755, 'network_depth': 6, 'filters_number': 95, 'max_kernel_size': 41}
#
# Model description:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 512, 9)]     0           []
#
#  batch_normalization_7 (BatchNo  (None, 512, 9)      36          ['input_2[0][0]']
#  rmalization)
#
#  conv1d_8 (Conv1D)              (None, 512, 32)      288         ['batch_normalization_7[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 512, 9)       0           ['batch_normalization_7[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 512, 95)      124640      ['conv1d_8[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 512, 95)      60800       ['conv1d_8[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 512, 95)      30400       ['conv1d_8[0][0]']
#
#  conv1d_12 (Conv1D)             (None, 512, 95)      855         ['max_pooling1d[0][0]']
#
#  concatenate (Concatenate)      (None, 512, 380)     0           ['conv1d_9[0][0]',
#                                                                   'conv1d_10[0][0]',
#                                                                   'conv1d_11[0][0]',
#                                                                   'conv1d_12[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 512, 380)    1520        ['concatenate[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 512, 380)     0           ['batch_normalization_8[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 512, 32)      12160       ['activation_1[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 512, 380)    0           ['activation_1[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 512, 95)      124640      ['conv1d_13[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 512, 95)      60800       ['conv1d_13[0][0]']
#
#  conv1d_16 (Conv1D)             (None, 512, 95)      30400       ['conv1d_13[0][0]']
#
#  conv1d_17 (Conv1D)             (None, 512, 95)      36100       ['max_pooling1d_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 512, 380)     0           ['conv1d_14[0][0]',
#                                                                   'conv1d_15[0][0]',
#                                                                   'conv1d_16[0][0]',
#                                                                   'conv1d_17[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 512, 380)    1520        ['concatenate_1[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 512, 380)     0           ['batch_normalization_9[0][0]']
#
#  conv1d_18 (Conv1D)             (None, 512, 32)      12160       ['activation_2[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 512, 380)    0           ['activation_2[0][0]']
#
#  conv1d_19 (Conv1D)             (None, 512, 95)      124640      ['conv1d_18[0][0]']
#
#  conv1d_20 (Conv1D)             (None, 512, 95)      60800       ['conv1d_18[0][0]']
#
#  conv1d_21 (Conv1D)             (None, 512, 95)      30400       ['conv1d_18[0][0]']
#
#  conv1d_22 (Conv1D)             (None, 512, 95)      36100       ['max_pooling1d_2[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 512, 380)     0           ['conv1d_19[0][0]',
#                                                                   'conv1d_20[0][0]',
#                                                                   'conv1d_21[0][0]',
#                                                                   'conv1d_22[0][0]']
#
#  conv1d_23 (Conv1D)             (None, 512, 380)     3420        ['batch_normalization_7[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 512, 380)    1520        ['concatenate_2[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 512, 380)    1520        ['conv1d_23[0][0]']
#  ormalization)
#
#  activation_3 (Activation)      (None, 512, 380)     0           ['batch_normalization_10[0][0]']
#
#  add_2 (Add)                    (None, 512, 380)     0           ['batch_normalization_11[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_4 (Activation)      (None, 512, 380)     0           ['add_2[0][0]']
#
#  conv1d_24 (Conv1D)             (None, 512, 32)      12160       ['activation_4[0][0]']
#
#  max_pooling1d_3 (MaxPooling1D)  (None, 512, 380)    0           ['activation_4[0][0]']
#
#  conv1d_25 (Conv1D)             (None, 512, 95)      124640      ['conv1d_24[0][0]']
#
#  conv1d_26 (Conv1D)             (None, 512, 95)      60800       ['conv1d_24[0][0]']
#
#  conv1d_27 (Conv1D)             (None, 512, 95)      30400       ['conv1d_24[0][0]']
#
#  conv1d_28 (Conv1D)             (None, 512, 95)      36100       ['max_pooling1d_3[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 512, 380)     0           ['conv1d_25[0][0]',
#                                                                   'conv1d_26[0][0]',
#                                                                   'conv1d_27[0][0]',
#                                                                   'conv1d_28[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 512, 380)    1520        ['concatenate_3[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 512, 380)     0           ['batch_normalization_12[0][0]']
#
#  conv1d_29 (Conv1D)             (None, 512, 32)      12160       ['activation_5[0][0]']
#
#  max_pooling1d_4 (MaxPooling1D)  (None, 512, 380)    0           ['activation_5[0][0]']
#
#  conv1d_30 (Conv1D)             (None, 512, 95)      124640      ['conv1d_29[0][0]']
#
#  conv1d_31 (Conv1D)             (None, 512, 95)      60800       ['conv1d_29[0][0]']
#
#  conv1d_32 (Conv1D)             (None, 512, 95)      30400       ['conv1d_29[0][0]']
#
#  conv1d_33 (Conv1D)             (None, 512, 95)      36100       ['max_pooling1d_4[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 512, 380)     0           ['conv1d_30[0][0]',
#                                                                   'conv1d_31[0][0]',
#                                                                   'conv1d_32[0][0]',
#                                                                   'conv1d_33[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 512, 380)    1520        ['concatenate_4[0][0]']
#  ormalization)
#
#  activation_6 (Activation)      (None, 512, 380)     0           ['batch_normalization_13[0][0]']
#
#  conv1d_34 (Conv1D)             (None, 512, 32)      12160       ['activation_6[0][0]']
#
#  max_pooling1d_5 (MaxPooling1D)  (None, 512, 380)    0           ['activation_6[0][0]']
#
#  conv1d_35 (Conv1D)             (None, 512, 95)      124640      ['conv1d_34[0][0]']
#
#  conv1d_36 (Conv1D)             (None, 512, 95)      60800       ['conv1d_34[0][0]']
#
#  conv1d_37 (Conv1D)             (None, 512, 95)      30400       ['conv1d_34[0][0]']
#
#  conv1d_38 (Conv1D)             (None, 512, 95)      36100       ['max_pooling1d_5[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 512, 380)     0           ['conv1d_35[0][0]',
#                                                                   'conv1d_36[0][0]',
#                                                                   'conv1d_37[0][0]',
#                                                                   'conv1d_38[0][0]']
#
#  conv1d_39 (Conv1D)             (None, 512, 380)     144400      ['activation_4[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 512, 380)    1520        ['concatenate_5[0][0]']
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 512, 380)    1520        ['conv1d_39[0][0]']
#  ormalization)
#
#  activation_7 (Activation)      (None, 512, 380)     0           ['batch_normalization_14[0][0]']
#
#  add_3 (Add)                    (None, 512, 380)     0           ['batch_normalization_15[0][0]',
#                                                                   'activation_7[0][0]']
#
#  activation_8 (Activation)      (None, 512, 380)     0           ['add_3[0][0]']
#
#  global_average_pooling1d_1 (Gl  (None, 380)         0           ['activation_8[0][0]']
#  obalAveragePooling1D)
#
#  dense_1 (Dense)                (None, 7)            2667        ['global_average_pooling1d_1[0][0
#                                                                  ]']
#
#  activation_9 (Activation)      (None, 7)            0           ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 1,700,166
# Trainable params: 1,694,068
# Non-trainable params: 6,098
# __________________________________________________________________________________________________
#
# -------------------------------------------------------------------------------------------------------
# Model 2
#
# Model type: DeepConvLSTM
#
# Hyperparameters:
# {'learning_rate': 0.015831358176124015, 'regularization_rate': 0.0013696149935263995, 'filters': [49, 77, 14, 52, 61, 48], 'lstm_dims': [43, 68, 77]}
#
# Model description:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_16 (Bat  (None, 512, 9)           36
#  chNormalization)
#
#  reshape (Reshape)           (None, 512, 9, 1)         0
#
#  conv2d (Conv2D)             (None, 512, 9, 49)        196
#
#  batch_normalization_17 (Bat  (None, 512, 9, 49)       196
#  chNormalization)
#
#  activation_10 (Activation)  (None, 512, 9, 49)        0
#
#  conv2d_1 (Conv2D)           (None, 512, 9, 77)        11396
#
#  batch_normalization_18 (Bat  (None, 512, 9, 77)       308
#  chNormalization)
#
#  activation_11 (Activation)  (None, 512, 9, 77)        0
#
#  conv2d_2 (Conv2D)           (None, 512, 9, 14)        3248
#
#  batch_normalization_19 (Bat  (None, 512, 9, 14)       56
#  chNormalization)
#
#  activation_12 (Activation)  (None, 512, 9, 14)        0
#
#  conv2d_3 (Conv2D)           (None, 512, 9, 52)        2236
#
#  batch_normalization_20 (Bat  (None, 512, 9, 52)       208
#  chNormalization)
#
#  activation_13 (Activation)  (None, 512, 9, 52)        0
#
#  conv2d_4 (Conv2D)           (None, 512, 9, 61)        9577
#
#  batch_normalization_21 (Bat  (None, 512, 9, 61)       244
#  chNormalization)
#
#  activation_14 (Activation)  (None, 512, 9, 61)        0
#
#  conv2d_5 (Conv2D)           (None, 512, 9, 48)        8832
#
#  batch_normalization_22 (Bat  (None, 512, 9, 48)       192
#  chNormalization)
#
#  activation_15 (Activation)  (None, 512, 9, 48)        0
#
#  reshape_1 (Reshape)         (None, 512, 432)          0
#
#  lstm (LSTM)                 (None, 512, 43)           81872
#
#  lstm_1 (LSTM)               (None, 512, 68)           30464
#
#  lstm_2 (LSTM)               (None, 512, 77)           44968
#
#  dropout (Dropout)           (None, 512, 77)           0
#
#  time_distributed (TimeDistr  (None, 512, 7)           546
#  ibuted)
#
#  activation_16 (Activation)  (None, 512, 7)            0
#
#  lambda (Lambda)             (None, 7)                 0
#
# =================================================================
# Total params: 194,575
# Trainable params: 193,955
# Non-trainable params: 620
# _________________________________________________________________
#
# -------------------------------------------------------------------------------------------------------
# Model 3
#
# Model type: CNN
#
# Hyperparameters:
# {'learning_rate': 0.05768508925909494, 'regularization_rate': 0.003049732371636213, 'filters': array([93, 41, 76, 90, 62, 86, 60]), 'fc_hidden_nodes': 142}
#
# Model description:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_23 (Bat  (None, 512, 9)           36
#  chNormalization)
#
#  conv1d_40 (Conv1D)          (None, 512, 93)           2604
#
#  batch_normalization_24 (Bat  (None, 512, 93)          372
#  chNormalization)
#
#  activation_17 (Activation)  (None, 512, 93)           0
#
#  conv1d_41 (Conv1D)          (None, 512, 41)           11480
#
#  batch_normalization_25 (Bat  (None, 512, 41)          164
#  chNormalization)
#
#  activation_18 (Activation)  (None, 512, 41)           0
#
#  conv1d_42 (Conv1D)          (None, 512, 76)           9424
#
#  batch_normalization_26 (Bat  (None, 512, 76)          304
#  chNormalization)
#
#  activation_19 (Activation)  (None, 512, 76)           0
#
#  conv1d_43 (Conv1D)          (None, 512, 90)           20610
#
#  batch_normalization_27 (Bat  (None, 512, 90)          360
#  chNormalization)
#
#  activation_20 (Activation)  (None, 512, 90)           0
#
#  conv1d_44 (Conv1D)          (None, 512, 62)           16802
#
#  batch_normalization_28 (Bat  (None, 512, 62)          248
#  chNormalization)
#
#  activation_21 (Activation)  (None, 512, 62)           0
#
#  conv1d_45 (Conv1D)          (None, 512, 86)           16082
#
#  batch_normalization_29 (Bat  (None, 512, 86)          344
#  chNormalization)
#
#  activation_22 (Activation)  (None, 512, 86)           0
#
#  conv1d_46 (Conv1D)          (None, 512, 60)           15540
#
#  batch_normalization_30 (Bat  (None, 512, 60)          240
#  chNormalization)
#
#  activation_23 (Activation)  (None, 512, 60)           0
#
#  flatten (Flatten)           (None, 30720)             0
#
#  dense_3 (Dense)             (None, 142)               4362382
#
#  activation_24 (Activation)  (None, 142)               0
#
#  dense_4 (Dense)             (None, 7)                 1001
#
#  batch_normalization_31 (Bat  (None, 7)                28
#  chNormalization)
#
#  activation_25 (Activation)  (None, 7)                 0
#
# =================================================================
# Total params: 4,458,021
# Trainable params: 4,456,973
# Non-trainable params: 1,048
# _________________________________________________________________

# %% [markdown]
# ## Compare models
# Now that the model architectures have been generated it is time to compare the models by training them on a subset of the training data and evaluating the models on the validation subset. This will help us to choose the best candidate model. The performance results for the models are stored in a json file, which we will visually inspect later on.

# %%
# Define directory where the results, e.g. json file, will be stored
resultpath = os.path.join(directory_to_extract_to, 'data/models/accelerometer')
if not os.path.exists(resultpath):
    os.makedirs(resultpath)

# %% [markdown]
# We are now going to train each of the models that we generated. On the one hand we want to train them as quickly as possible in order to be able to pick the best one as soon as possible. On the other hand we have to train each model long enough to get a good impression of its potential.
#
# We can influence the train time by adjusting the number of data samples that are used. This can be set with the argument 'subset_size'. We can also adjust the number of times the subset is iterated over. This number is called an epoch. We recommend to start with no more than 5 epochs and a maximum subset size of 300. You can experiment with these numbers.

# %%
outputfile = os.path.join(resultpath, 'modelcomparison.json')
histories, val_accuracies, val_losses = mcfly.find_architecture.train_models_on_samples(
    X_train, y_train_binary,
    X_val, y_val_binary,
    models,
    nr_epochs=4,
    subset_size=1000,
    early_stopping_patience=2,
    verbose=True,
    outputfile=outputfile,
    metric=metric)
print('Details of the training process were stored in ',outputfile)
# Out:
# Generated models will be trained on subset of the data (subset size: 1000).
# Training model 0 ResNet
# Epoch 1/4
# c:\Users\Phili\anaconda3\envs\chatbots\lib\site-packages\mcfly\find_architecture.py:137: UserWarning: Argument 'metric' is deprecated and will be ignored.
#   warnings.warn("Argument 'metric' is deprecated and will be ignored.")
# 50/50 [==============================] - 12s 174ms/step - loss: 0.7729 - accuracy: 0.7460 - val_loss: 46.6790 - val_accuracy: 0.3700
# Epoch 2/4
# 50/50 [==============================] - 8s 163ms/step - loss: 0.4307 - accuracy: 0.8700 - val_loss: 26.0054 - val_accuracy: 0.3000
# Epoch 3/4
# 50/50 [==============================] - 8s 163ms/step - loss: 0.3218 - accuracy: 0.9000 - val_loss: 6.5025 - val_accuracy: 0.5800
# Epoch 4/4
# 50/50 [==============================] - 8s 167ms/step - loss: 0.2832 - accuracy: 0.9140 - val_loss: 2.9811 - val_accuracy: 0.7200
# Training model 1 InceptionTime
# Epoch 1/4
# 50/50 [==============================] - 105s 2s/step - loss: 1.2963 - accuracy: 0.7310 - val_loss: 1147.9438 - val_accuracy: 0.1300
# Epoch 2/4
# 50/50 [==============================] - 122s 2s/step - loss: 0.4280 - accuracy: 0.8630 - val_loss: 53.7568 - val_accuracy: 0.3800
# Epoch 3/4
# 50/50 [==============================] - 121s 2s/step - loss: 0.2740 - accuracy: 0.9010 - val_loss: 2.4773 - val_accuracy: 0.6900
# Epoch 4/4
# 50/50 [==============================] - 123s 2s/step - loss: 0.2497 - accuracy: 0.9070 - val_loss: 0.4681 - val_accuracy: 0.8900
# Training model 2 DeepConvLSTM
# Epoch 1/4
# 50/50 [==============================] - 108s 2s/step - loss: 2.0757 - accuracy: 0.3280 - val_loss: 4.5932 - val_accuracy: 0.2800
# Epoch 2/4
# 50/50 [==============================] - 97s 2s/step - loss: 1.7174 - accuracy: 0.3930 - val_loss: 2.4500 - val_accuracy: 0.1800
# Epoch 3/4
# 50/50 [==============================] - 98s 2s/step - loss: 1.8338 - accuracy: 0.3940 - val_loss: 2.1584 - val_accuracy: 0.3100
# Epoch 4/4
# 50/50 [==============================] - 97s 2s/step - loss: 1.6482 - accuracy: 0.4600 - val_loss: 2.0270 - val_accuracy: 0.3200
# Training model 3 CNN
# Epoch 1/4
# 50/50 [==============================] - 20s 336ms/step - loss: 99.9919 - accuracy: 0.4930 - val_loss: 111.7054 - val_accuracy: 0.1300
# Epoch 2/4
# 50/50 [==============================] - 15s 292ms/step - loss: 4.3599 - accuracy: 0.5440 - val_loss: 11.8267 - val_accuracy: 0.1300
# Epoch 3/4
# 50/50 [==============================] - 14s 274ms/step - loss: 3.4301 - accuracy: 0.5440 - val_loss: 44.1721 - val_accuracy: 0.1500
# Epoch 4/4
# 50/50 [==============================] - 14s 281ms/step - loss: 3.2908 - accuracy: 0.5040 - val_loss: 5.9486 - val_accuracy: 0.2900
# Details of the training process were stored in  data/data/models/accelerometer\modelcomparison.json

# %% [markdown]
# # Inspect model performance (Visualization)
#
# We can inspect the learning process in the visualization tool on http://nlesc.github.io/mcfly/.
#
# Alternatively, you can run the visualization from a local web service:
# - Clone the mcfly github repository (if you haven't done so already for visualization)
#
#  `git clone https://github.com/NLeSC/mcfly`
#
#
# - navigate to the html folder:
#
#  `cd mcfly/html`
#
#
# - Start a web server. This can be done in various ways, for example:
#  - `python3 -m http.server` (or. `python -m http.server`)
#
# Notice the port number the web server is serving on. This is usually 8000.
# With a web browser, navigate to [localhost:8000](localhost:8000).
#
# You need to upload the json file that contains the details of the training process. The following line of code shows the path to this file:

# %%
outputfile

# %% [markdown]
# ### *Question 5:  Look at the visualization. Which model performs best?*
# ### *Question 6:  Did you train all models with a sufficient number of iterations?*

# %% [markdown]
# # Inspect model performance (table)
#
# Let's compare the performance of the models by showing the results as a table.

# %%
metric = 'accuracy'
modelcomparisons = pd.DataFrame({'model':[str(params) for model, params, model_types in models],
                       'train_{}'.format(metric): [history.history[metric][-1] for history in histories],
                       'train_loss': [history.history['loss'][-1] for history in histories],
                       'val_{}'.format(metric): [history.history['val_{}'.format(metric)][-1] for history in histories],
                       'val_loss': [history.history['val_loss'][-1] for history in histories]
                       })
modelcomparisons.to_csv(os.path.join(resultpath, 'modelcomparisons01.csv'))

modelcomparisons

# %% [markdown]
# # Second iteration

# %%
# if you want --> run a second search iteration

# %%
models = mcfly.modelgen.generate_models(X_train.shape,
                                        number_of_output_dimensions=num_classes,
                                        number_of_models = 3,
                                        model_types = ['InceptionTime'],
                                        metrics=[metric]
                                       )
# Out:
# c:\Users\Phili\anaconda3\envs\chatbots\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
models_to_print = range(len(models))
for i, item in enumerate(models):
    if i in models_to_print:
        model, params, model_types = item
        print("-------------------------------------------------------------------------------------------------------")
        print("Model " + str(i), '\n')          
        print("Model type:", model_types, '\n')        
        print("Hyperparameters:")
        print(params)
        print(" ")
        print("Model description:")
        model.summary()        
        print(" ")
# Out:
# -------------------------------------------------------------------------------------------------------
# Model 0
#
# Model type: InceptionTime
#
# Hyperparameters:
# {'learning_rate': 0.004741712758572711, 'regularization_rate': 0.0030760874784206507, 'network_depth': 6, 'filters_number': 62, 'max_kernel_size': 87}
#
# Model description:
# Model: "model_12"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_13 (InputLayer)          [(None, 512, 9)]     0           []
#
#  batch_normalization_97 (BatchN  (None, 512, 9)      36          ['input_13[0][0]']
#  ormalization)
#
#  conv1d_278 (Conv1D)            (None, 512, 32)      288         ['batch_normalization_97[0][0]']
#
#  max_pooling1d_50 (MaxPooling1D  (None, 512, 9)      0           ['batch_normalization_97[0][0]']
#  )
#
#  conv1d_279 (Conv1D)            (None, 512, 62)      172608      ['conv1d_278[0][0]']
#
#  conv1d_280 (Conv1D)            (None, 512, 62)      85312       ['conv1d_278[0][0]']
#
#  conv1d_281 (Conv1D)            (None, 512, 62)      41664       ['conv1d_278[0][0]']
#
#  conv1d_282 (Conv1D)            (None, 512, 62)      558         ['max_pooling1d_50[0][0]']
#
#  concatenate_50 (Concatenate)   (None, 512, 248)     0           ['conv1d_279[0][0]',
#                                                                   'conv1d_280[0][0]',
#                                                                   'conv1d_281[0][0]',
#                                                                   'conv1d_282[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 512, 248)    992         ['concatenate_50[0][0]']
#  ormalization)
#
#  activation_91 (Activation)     (None, 512, 248)     0           ['batch_normalization_98[0][0]']
#
#  conv1d_283 (Conv1D)            (None, 512, 32)      7936        ['activation_91[0][0]']
#
#  max_pooling1d_51 (MaxPooling1D  (None, 512, 248)    0           ['activation_91[0][0]']
#  )
#
#  conv1d_284 (Conv1D)            (None, 512, 62)      172608      ['conv1d_283[0][0]']
#
#  conv1d_285 (Conv1D)            (None, 512, 62)      85312       ['conv1d_283[0][0]']
#
#  conv1d_286 (Conv1D)            (None, 512, 62)      41664       ['conv1d_283[0][0]']
#
#  conv1d_287 (Conv1D)            (None, 512, 62)      15376       ['max_pooling1d_51[0][0]']
#
#  concatenate_51 (Concatenate)   (None, 512, 248)     0           ['conv1d_284[0][0]',
#                                                                   'conv1d_285[0][0]',
#                                                                   'conv1d_286[0][0]',
#                                                                   'conv1d_287[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 512, 248)    992         ['concatenate_51[0][0]']
#  ormalization)
#
#  activation_92 (Activation)     (None, 512, 248)     0           ['batch_normalization_99[0][0]']
#
#  conv1d_288 (Conv1D)            (None, 512, 32)      7936        ['activation_92[0][0]']
#
#  max_pooling1d_52 (MaxPooling1D  (None, 512, 248)    0           ['activation_92[0][0]']
#  )
#
#  conv1d_289 (Conv1D)            (None, 512, 62)      172608      ['conv1d_288[0][0]']
#
#  conv1d_290 (Conv1D)            (None, 512, 62)      85312       ['conv1d_288[0][0]']
#
#  conv1d_291 (Conv1D)            (None, 512, 62)      41664       ['conv1d_288[0][0]']
#
#  conv1d_292 (Conv1D)            (None, 512, 62)      15376       ['max_pooling1d_52[0][0]']
#
#  concatenate_52 (Concatenate)   (None, 512, 248)     0           ['conv1d_289[0][0]',
#                                                                   'conv1d_290[0][0]',
#                                                                   'conv1d_291[0][0]',
#                                                                   'conv1d_292[0][0]']
#
#  conv1d_293 (Conv1D)            (None, 512, 248)     2232        ['batch_normalization_97[0][0]']
#
#  batch_normalization_100 (Batch  (None, 512, 248)    992         ['concatenate_52[0][0]']
#  Normalization)
#
#  batch_normalization_101 (Batch  (None, 512, 248)    992         ['conv1d_293[0][0]']
#  Normalization)
#
#  activation_93 (Activation)     (None, 512, 248)     0           ['batch_normalization_100[0][0]']
#
#  add_15 (Add)                   (None, 512, 248)     0           ['batch_normalization_101[0][0]',
#                                                                   'activation_93[0][0]']
#
#  activation_94 (Activation)     (None, 512, 248)     0           ['add_15[0][0]']
#
#  conv1d_294 (Conv1D)            (None, 512, 32)      7936        ['activation_94[0][0]']
#
#  max_pooling1d_53 (MaxPooling1D  (None, 512, 248)    0           ['activation_94[0][0]']
#  )
#
#  conv1d_295 (Conv1D)            (None, 512, 62)      172608      ['conv1d_294[0][0]']
#
#  conv1d_296 (Conv1D)            (None, 512, 62)      85312       ['conv1d_294[0][0]']
#
#  conv1d_297 (Conv1D)            (None, 512, 62)      41664       ['conv1d_294[0][0]']
#
#  conv1d_298 (Conv1D)            (None, 512, 62)      15376       ['max_pooling1d_53[0][0]']
#
#  concatenate_53 (Concatenate)   (None, 512, 248)     0           ['conv1d_295[0][0]',
#                                                                   'conv1d_296[0][0]',
#                                                                   'conv1d_297[0][0]',
#                                                                   'conv1d_298[0][0]']
#
#  batch_normalization_102 (Batch  (None, 512, 248)    992         ['concatenate_53[0][0]']
#  Normalization)
#
#  activation_95 (Activation)     (None, 512, 248)     0           ['batch_normalization_102[0][0]']
#
#  conv1d_299 (Conv1D)            (None, 512, 32)      7936        ['activation_95[0][0]']
#
#  max_pooling1d_54 (MaxPooling1D  (None, 512, 248)    0           ['activation_95[0][0]']
#  )
#
#  conv1d_300 (Conv1D)            (None, 512, 62)      172608      ['conv1d_299[0][0]']
#
#  conv1d_301 (Conv1D)            (None, 512, 62)      85312       ['conv1d_299[0][0]']
#
#  conv1d_302 (Conv1D)            (None, 512, 62)      41664       ['conv1d_299[0][0]']
#
#  conv1d_303 (Conv1D)            (None, 512, 62)      15376       ['max_pooling1d_54[0][0]']
#
#  concatenate_54 (Concatenate)   (None, 512, 248)     0           ['conv1d_300[0][0]',
#                                                                   'conv1d_301[0][0]',
#                                                                   'conv1d_302[0][0]',
#                                                                   'conv1d_303[0][0]']
#
#  batch_normalization_103 (Batch  (None, 512, 248)    992         ['concatenate_54[0][0]']
#  Normalization)
#
#  activation_96 (Activation)     (None, 512, 248)     0           ['batch_normalization_103[0][0]']
#
#  conv1d_304 (Conv1D)            (None, 512, 32)      7936        ['activation_96[0][0]']
#
#  max_pooling1d_55 (MaxPooling1D  (None, 512, 248)    0           ['activation_96[0][0]']
#  )
#
#  conv1d_305 (Conv1D)            (None, 512, 62)      172608      ['conv1d_304[0][0]']
#
#  conv1d_306 (Conv1D)            (None, 512, 62)      85312       ['conv1d_304[0][0]']
#
#  conv1d_307 (Conv1D)            (None, 512, 62)      41664       ['conv1d_304[0][0]']
#
#  conv1d_308 (Conv1D)            (None, 512, 62)      15376       ['max_pooling1d_55[0][0]']
#
#  concatenate_55 (Concatenate)   (None, 512, 248)     0           ['conv1d_305[0][0]',
#                                                                   'conv1d_306[0][0]',
#                                                                   'conv1d_307[0][0]',
#                                                                   'conv1d_308[0][0]']
#
#  conv1d_309 (Conv1D)            (None, 512, 248)     61504       ['activation_94[0][0]']
#
#  batch_normalization_104 (Batch  (None, 512, 248)    992         ['concatenate_55[0][0]']
#  Normalization)
#
#  batch_normalization_105 (Batch  (None, 512, 248)    992         ['conv1d_309[0][0]']
#  Normalization)
#
#  activation_97 (Activation)     (None, 512, 248)     0           ['batch_normalization_104[0][0]']
#
#  add_16 (Add)                   (None, 512, 248)     0           ['batch_normalization_105[0][0]',
#                                                                   'activation_97[0][0]']
#
#  activation_98 (Activation)     (None, 512, 248)     0           ['add_16[0][0]']
#
#  global_average_pooling1d_12 (G  (None, 248)         0           ['activation_98[0][0]']
#  lobalAveragePooling1D)
#
#  dense_15 (Dense)               (None, 7)            1743        ['global_average_pooling1d_12[0][
#                                                                  0]']
#
#  activation_99 (Activation)     (None, 7)            0           ['dense_15[0][0]']
#
# ==================================================================================================
# Total params: 1,988,361
# Trainable params: 1,984,375
# Non-trainable params: 3,986
# __________________________________________________________________________________________________
#
# -------------------------------------------------------------------------------------------------------
# Model 1
#
# Model type: InceptionTime
#
# Hyperparameters:
# {'learning_rate': 0.0019013957308651832, 'regularization_rate': 0.006579609441735624, 'network_depth': 6, 'filters_number': 52, 'max_kernel_size': 32}
#
# Model description:
# Model: "model_13"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_14 (InputLayer)          [(None, 512, 9)]     0           []
#
#  batch_normalization_106 (Batch  (None, 512, 9)      36          ['input_14[0][0]']
#  Normalization)
#
#  conv1d_310 (Conv1D)            (None, 512, 32)      288         ['batch_normalization_106[0][0]']
#
#  max_pooling1d_56 (MaxPooling1D  (None, 512, 9)      0           ['batch_normalization_106[0][0]']
#  )
#
#  conv1d_311 (Conv1D)            (None, 512, 52)      53248       ['conv1d_310[0][0]']
#
#  conv1d_312 (Conv1D)            (None, 512, 52)      26624       ['conv1d_310[0][0]']
#
#  conv1d_313 (Conv1D)            (None, 512, 52)      13312       ['conv1d_310[0][0]']
#
#  conv1d_314 (Conv1D)            (None, 512, 52)      468         ['max_pooling1d_56[0][0]']
#
#  concatenate_56 (Concatenate)   (None, 512, 208)     0           ['conv1d_311[0][0]',
#                                                                   'conv1d_312[0][0]',
#                                                                   'conv1d_313[0][0]',
#                                                                   'conv1d_314[0][0]']
#
#  batch_normalization_107 (Batch  (None, 512, 208)    832         ['concatenate_56[0][0]']
#  Normalization)
#
#  activation_100 (Activation)    (None, 512, 208)     0           ['batch_normalization_107[0][0]']
#
#  conv1d_315 (Conv1D)            (None, 512, 32)      6656        ['activation_100[0][0]']
#
#  max_pooling1d_57 (MaxPooling1D  (None, 512, 208)    0           ['activation_100[0][0]']
#  )
#
#  conv1d_316 (Conv1D)            (None, 512, 52)      53248       ['conv1d_315[0][0]']
#
#  conv1d_317 (Conv1D)            (None, 512, 52)      26624       ['conv1d_315[0][0]']
#
#  conv1d_318 (Conv1D)            (None, 512, 52)      13312       ['conv1d_315[0][0]']
#
#  conv1d_319 (Conv1D)            (None, 512, 52)      10816       ['max_pooling1d_57[0][0]']
#
#  concatenate_57 (Concatenate)   (None, 512, 208)     0           ['conv1d_316[0][0]',
#                                                                   'conv1d_317[0][0]',
#                                                                   'conv1d_318[0][0]',
#                                                                   'conv1d_319[0][0]']
#
#  batch_normalization_108 (Batch  (None, 512, 208)    832         ['concatenate_57[0][0]']
#  Normalization)
#
#  activation_101 (Activation)    (None, 512, 208)     0           ['batch_normalization_108[0][0]']
#
#  conv1d_320 (Conv1D)            (None, 512, 32)      6656        ['activation_101[0][0]']
#
#  max_pooling1d_58 (MaxPooling1D  (None, 512, 208)    0           ['activation_101[0][0]']
#  )
#
#  conv1d_321 (Conv1D)            (None, 512, 52)      53248       ['conv1d_320[0][0]']
#
#  conv1d_322 (Conv1D)            (None, 512, 52)      26624       ['conv1d_320[0][0]']
#
#  conv1d_323 (Conv1D)            (None, 512, 52)      13312       ['conv1d_320[0][0]']
#
#  conv1d_324 (Conv1D)            (None, 512, 52)      10816       ['max_pooling1d_58[0][0]']
#
#  concatenate_58 (Concatenate)   (None, 512, 208)     0           ['conv1d_321[0][0]',
#                                                                   'conv1d_322[0][0]',
#                                                                   'conv1d_323[0][0]',
#                                                                   'conv1d_324[0][0]']
#
#  conv1d_325 (Conv1D)            (None, 512, 208)     1872        ['batch_normalization_106[0][0]']
#
#  batch_normalization_109 (Batch  (None, 512, 208)    832         ['concatenate_58[0][0]']
#  Normalization)
#
#  batch_normalization_110 (Batch  (None, 512, 208)    832         ['conv1d_325[0][0]']
#  Normalization)
#
#  activation_102 (Activation)    (None, 512, 208)     0           ['batch_normalization_109[0][0]']
#
#  add_17 (Add)                   (None, 512, 208)     0           ['batch_normalization_110[0][0]',
#                                                                   'activation_102[0][0]']
#
#  activation_103 (Activation)    (None, 512, 208)     0           ['add_17[0][0]']
#
#  conv1d_326 (Conv1D)            (None, 512, 32)      6656        ['activation_103[0][0]']
#
#  max_pooling1d_59 (MaxPooling1D  (None, 512, 208)    0           ['activation_103[0][0]']
#  )
#
#  conv1d_327 (Conv1D)            (None, 512, 52)      53248       ['conv1d_326[0][0]']
#
#  conv1d_328 (Conv1D)            (None, 512, 52)      26624       ['conv1d_326[0][0]']
#
#  conv1d_329 (Conv1D)            (None, 512, 52)      13312       ['conv1d_326[0][0]']
#
#  conv1d_330 (Conv1D)            (None, 512, 52)      10816       ['max_pooling1d_59[0][0]']
#
#  concatenate_59 (Concatenate)   (None, 512, 208)     0           ['conv1d_327[0][0]',
#                                                                   'conv1d_328[0][0]',
#                                                                   'conv1d_329[0][0]',
#                                                                   'conv1d_330[0][0]']
#
#  batch_normalization_111 (Batch  (None, 512, 208)    832         ['concatenate_59[0][0]']
#  Normalization)
#
#  activation_104 (Activation)    (None, 512, 208)     0           ['batch_normalization_111[0][0]']
#
#  conv1d_331 (Conv1D)            (None, 512, 32)      6656        ['activation_104[0][0]']
#
#  max_pooling1d_60 (MaxPooling1D  (None, 512, 208)    0           ['activation_104[0][0]']
#  )
#
#  conv1d_332 (Conv1D)            (None, 512, 52)      53248       ['conv1d_331[0][0]']
#
#  conv1d_333 (Conv1D)            (None, 512, 52)      26624       ['conv1d_331[0][0]']
#
#  conv1d_334 (Conv1D)            (None, 512, 52)      13312       ['conv1d_331[0][0]']
#
#  conv1d_335 (Conv1D)            (None, 512, 52)      10816       ['max_pooling1d_60[0][0]']
#
#  concatenate_60 (Concatenate)   (None, 512, 208)     0           ['conv1d_332[0][0]',
#                                                                   'conv1d_333[0][0]',
#                                                                   'conv1d_334[0][0]',
#                                                                   'conv1d_335[0][0]']
#
#  batch_normalization_112 (Batch  (None, 512, 208)    832         ['concatenate_60[0][0]']
#  Normalization)
#
#  activation_105 (Activation)    (None, 512, 208)     0           ['batch_normalization_112[0][0]']
#
#  conv1d_336 (Conv1D)            (None, 512, 32)      6656        ['activation_105[0][0]']
#
#  max_pooling1d_61 (MaxPooling1D  (None, 512, 208)    0           ['activation_105[0][0]']
#  )
#
#  conv1d_337 (Conv1D)            (None, 512, 52)      53248       ['conv1d_336[0][0]']
#
#  conv1d_338 (Conv1D)            (None, 512, 52)      26624       ['conv1d_336[0][0]']
#
#  conv1d_339 (Conv1D)            (None, 512, 52)      13312       ['conv1d_336[0][0]']
#
#  conv1d_340 (Conv1D)            (None, 512, 52)      10816       ['max_pooling1d_61[0][0]']
#
#  concatenate_61 (Concatenate)   (None, 512, 208)     0           ['conv1d_337[0][0]',
#                                                                   'conv1d_338[0][0]',
#                                                                   'conv1d_339[0][0]',
#                                                                   'conv1d_340[0][0]']
#
#  conv1d_341 (Conv1D)            (None, 512, 208)     43264       ['activation_103[0][0]']
#
#  batch_normalization_113 (Batch  (None, 512, 208)    832         ['concatenate_61[0][0]']
#  Normalization)
#
#  batch_normalization_114 (Batch  (None, 512, 208)    832         ['conv1d_341[0][0]']
#  Normalization)
#
#  activation_106 (Activation)    (None, 512, 208)     0           ['batch_normalization_113[0][0]']
#
#  add_18 (Add)                   (None, 512, 208)     0           ['batch_normalization_114[0][0]',
#                                                                   'activation_106[0][0]']
#
#  activation_107 (Activation)    (None, 512, 208)     0           ['add_18[0][0]']
#
#  global_average_pooling1d_13 (G  (None, 208)         0           ['activation_107[0][0]']
#  lobalAveragePooling1D)
#
#  dense_16 (Dense)               (None, 7)            1463        ['global_average_pooling1d_13[0][
#                                                                  0]']
#
#  activation_108 (Activation)    (None, 7)            0           ['dense_16[0][0]']
#
# ==================================================================================================
# Total params: 700,511
# Trainable params: 697,165
# Non-trainable params: 3,346
# __________________________________________________________________________________________________
#
# -------------------------------------------------------------------------------------------------------
# Model 2
#
# Model type: InceptionTime
#
# Hyperparameters:
# {'learning_rate': 0.0006523858178152041, 'regularization_rate': 0.00856523165407815, 'network_depth': 6, 'filters_number': 59, 'max_kernel_size': 10}
#
# Model description:
# Model: "model_14"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_15 (InputLayer)          [(None, 512, 9)]     0           []
#
#  batch_normalization_115 (Batch  (None, 512, 9)      36          ['input_15[0][0]']
#  Normalization)
#
#  conv1d_342 (Conv1D)            (None, 512, 32)      288         ['batch_normalization_115[0][0]']
#
#  max_pooling1d_62 (MaxPooling1D  (None, 512, 9)      0           ['batch_normalization_115[0][0]']
#  )
#
#  conv1d_343 (Conv1D)            (None, 512, 59)      18880       ['conv1d_342[0][0]']
#
#  conv1d_344 (Conv1D)            (None, 512, 59)      9440        ['conv1d_342[0][0]']
#
#  conv1d_345 (Conv1D)            (None, 512, 59)      3776        ['conv1d_342[0][0]']
#
#  conv1d_346 (Conv1D)            (None, 512, 59)      531         ['max_pooling1d_62[0][0]']
#
#  concatenate_62 (Concatenate)   (None, 512, 236)     0           ['conv1d_343[0][0]',
#                                                                   'conv1d_344[0][0]',
#                                                                   'conv1d_345[0][0]',
#                                                                   'conv1d_346[0][0]']
#
#  batch_normalization_116 (Batch  (None, 512, 236)    944         ['concatenate_62[0][0]']
#  Normalization)
#
#  activation_109 (Activation)    (None, 512, 236)     0           ['batch_normalization_116[0][0]']
#
#  conv1d_347 (Conv1D)            (None, 512, 32)      7552        ['activation_109[0][0]']
#
#  max_pooling1d_63 (MaxPooling1D  (None, 512, 236)    0           ['activation_109[0][0]']
#  )
#
#  conv1d_348 (Conv1D)            (None, 512, 59)      18880       ['conv1d_347[0][0]']
#
#  conv1d_349 (Conv1D)            (None, 512, 59)      9440        ['conv1d_347[0][0]']
#
#  conv1d_350 (Conv1D)            (None, 512, 59)      3776        ['conv1d_347[0][0]']
#
#  conv1d_351 (Conv1D)            (None, 512, 59)      13924       ['max_pooling1d_63[0][0]']
#
#  concatenate_63 (Concatenate)   (None, 512, 236)     0           ['conv1d_348[0][0]',
#                                                                   'conv1d_349[0][0]',
#                                                                   'conv1d_350[0][0]',
#                                                                   'conv1d_351[0][0]']
#
#  batch_normalization_117 (Batch  (None, 512, 236)    944         ['concatenate_63[0][0]']
#  Normalization)
#
#  activation_110 (Activation)    (None, 512, 236)     0           ['batch_normalization_117[0][0]']
#
#  conv1d_352 (Conv1D)            (None, 512, 32)      7552        ['activation_110[0][0]']
#
#  max_pooling1d_64 (MaxPooling1D  (None, 512, 236)    0           ['activation_110[0][0]']
#  )
#
#  conv1d_353 (Conv1D)            (None, 512, 59)      18880       ['conv1d_352[0][0]']
#
#  conv1d_354 (Conv1D)            (None, 512, 59)      9440        ['conv1d_352[0][0]']
#
#  conv1d_355 (Conv1D)            (None, 512, 59)      3776        ['conv1d_352[0][0]']
#
#  conv1d_356 (Conv1D)            (None, 512, 59)      13924       ['max_pooling1d_64[0][0]']
#
#  concatenate_64 (Concatenate)   (None, 512, 236)     0           ['conv1d_353[0][0]',
#                                                                   'conv1d_354[0][0]',
#                                                                   'conv1d_355[0][0]',
#                                                                   'conv1d_356[0][0]']
#
#  conv1d_357 (Conv1D)            (None, 512, 236)     2124        ['batch_normalization_115[0][0]']
#
#  batch_normalization_118 (Batch  (None, 512, 236)    944         ['concatenate_64[0][0]']
#  Normalization)
#
#  batch_normalization_119 (Batch  (None, 512, 236)    944         ['conv1d_357[0][0]']
#  Normalization)
#
#  activation_111 (Activation)    (None, 512, 236)     0           ['batch_normalization_118[0][0]']
#
#  add_19 (Add)                   (None, 512, 236)     0           ['batch_normalization_119[0][0]',
#                                                                   'activation_111[0][0]']
#
#  activation_112 (Activation)    (None, 512, 236)     0           ['add_19[0][0]']
#
#  conv1d_358 (Conv1D)            (None, 512, 32)      7552        ['activation_112[0][0]']
#
#  max_pooling1d_65 (MaxPooling1D  (None, 512, 236)    0           ['activation_112[0][0]']
#  )
#
#  conv1d_359 (Conv1D)            (None, 512, 59)      18880       ['conv1d_358[0][0]']
#
#  conv1d_360 (Conv1D)            (None, 512, 59)      9440        ['conv1d_358[0][0]']
#
#  conv1d_361 (Conv1D)            (None, 512, 59)      3776        ['conv1d_358[0][0]']
#
#  conv1d_362 (Conv1D)            (None, 512, 59)      13924       ['max_pooling1d_65[0][0]']
#
#  concatenate_65 (Concatenate)   (None, 512, 236)     0           ['conv1d_359[0][0]',
#                                                                   'conv1d_360[0][0]',
#                                                                   'conv1d_361[0][0]',
#                                                                   'conv1d_362[0][0]']
#
#  batch_normalization_120 (Batch  (None, 512, 236)    944         ['concatenate_65[0][0]']
#  Normalization)
#
#  activation_113 (Activation)    (None, 512, 236)     0           ['batch_normalization_120[0][0]']
#
#  conv1d_363 (Conv1D)            (None, 512, 32)      7552        ['activation_113[0][0]']
#
#  max_pooling1d_66 (MaxPooling1D  (None, 512, 236)    0           ['activation_113[0][0]']
#  )
#
#  conv1d_364 (Conv1D)            (None, 512, 59)      18880       ['conv1d_363[0][0]']
#
#  conv1d_365 (Conv1D)            (None, 512, 59)      9440        ['conv1d_363[0][0]']
#
#  conv1d_366 (Conv1D)            (None, 512, 59)      3776        ['conv1d_363[0][0]']
#
#  conv1d_367 (Conv1D)            (None, 512, 59)      13924       ['max_pooling1d_66[0][0]']
#
#  concatenate_66 (Concatenate)   (None, 512, 236)     0           ['conv1d_364[0][0]',
#                                                                   'conv1d_365[0][0]',
#                                                                   'conv1d_366[0][0]',
#                                                                   'conv1d_367[0][0]']
#
#  batch_normalization_121 (Batch  (None, 512, 236)    944         ['concatenate_66[0][0]']
#  Normalization)
#
#  activation_114 (Activation)    (None, 512, 236)     0           ['batch_normalization_121[0][0]']
#
#  conv1d_368 (Conv1D)            (None, 512, 32)      7552        ['activation_114[0][0]']
#
#  max_pooling1d_67 (MaxPooling1D  (None, 512, 236)    0           ['activation_114[0][0]']
#  )
#
#  conv1d_369 (Conv1D)            (None, 512, 59)      18880       ['conv1d_368[0][0]']
#
#  conv1d_370 (Conv1D)            (None, 512, 59)      9440        ['conv1d_368[0][0]']
#
#  conv1d_371 (Conv1D)            (None, 512, 59)      3776        ['conv1d_368[0][0]']
#
#  conv1d_372 (Conv1D)            (None, 512, 59)      13924       ['max_pooling1d_67[0][0]']
#
#  concatenate_67 (Concatenate)   (None, 512, 236)     0           ['conv1d_369[0][0]',
#                                                                   'conv1d_370[0][0]',
#                                                                   'conv1d_371[0][0]',
#                                                                   'conv1d_372[0][0]']
#
#  conv1d_373 (Conv1D)            (None, 512, 236)     55696       ['activation_112[0][0]']
#
#  batch_normalization_122 (Batch  (None, 512, 236)    944         ['concatenate_67[0][0]']
#  Normalization)
#
#  batch_normalization_123 (Batch  (None, 512, 236)    944         ['conv1d_373[0][0]']
#  Normalization)
#
#  activation_115 (Activation)    (None, 512, 236)     0           ['batch_normalization_122[0][0]']
#
#  add_20 (Add)                   (None, 512, 236)     0           ['batch_normalization_123[0][0]',
#                                                                   'activation_115[0][0]']
#
#  activation_116 (Activation)    (None, 512, 236)     0           ['add_20[0][0]']
#
#  global_average_pooling1d_14 (G  (None, 236)         0           ['activation_116[0][0]']
#  lobalAveragePooling1D)
#
#  dense_17 (Dense)               (None, 7)            1659        ['global_average_pooling1d_14[0][
#                                                                  0]']
#
#  activation_117 (Activation)    (None, 7)            0           ['dense_17[0][0]']
#
# ==================================================================================================
# Total params: 367,842
# Trainable params: 364,048
# Non-trainable params: 3,794
# __________________________________________________________________________________________________

# %%
outputfile = os.path.join(resultpath, 'modelcomparison2.json')
histories, val_accuracies, val_losses = mcfly.find_architecture.train_models_on_samples(
    X_train, y_train_binary,
    X_val, y_val_binary,
    models,
    nr_epochs=4,
    subset_size=1000, #normalerweise hoeher, nur zum testen. Aktuell overfitting
    early_stopping_patience=2,
    verbose=True,
    outputfile=outputfile,
    metric=metric)
print('Details of the training process were stored in ',outputfile)
# Out:
# Generated models will be trained on subset of the data (subset size: 1000).
# Training model 0 InceptionTime
# Epoch 1/4
# 11/50 [=====>........................] - ETA: 2:54 - loss: 1.2584 - accuracy: 0.6409
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Phili\Desktop\IntelligenteSysteme\ai_for_smart_health\ai_smart_health_08_accelerometer_data_template.ipynb Cell 43 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Phili/Desktop/IntelligenteSysteme/ai_for_smart_health/ai_smart_health_08_accelerometer_data_template.ipynb#X60sZmlsZQ%3D%3D?line=0'>1</a> outputfile = os.path.join(resultpath, 'modelcomparison2.json')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Phili/Desktop/IntelligenteSysteme/ai_for_smart_health/ai_smart_health_08_accelerometer_data_template.ipynb#X60sZmlsZQ%3D%3D?line=1'>2</a> histories, val_accuracies, val_losses = mcfly.find_architecture.train_models_on_samples(
#       <a href='vscode-notebook-cell:/c%3A/Users/Phili/Desktop/IntelligenteSysteme/ai_for_smart_health/ai_smart_health_08_accelerometer_data_template.ipynb#X60sZmlsZQ%3D%3D?line=2'>3</a>     X_train, y_train_binary,
#       <a href='vscode-notebook-cell:/c%3A/Users/Phili/Desktop/IntelligenteSysteme/ai_for_smart_health/ai_smart_health_08_accelerometer_data_template.ipynb#X60sZmlsZQ%3D%3D?line=3'>4</a>     X_val, y_val_binary,
#       <a href='vscode-notebook-cell:/c%3A/Users/Phili/Desktop/IntelligenteSysteme/ai_for_smart_health/ai_smart_health_08_accelerometer_data_template.ipynb#X60sZmlsZQ%3D%3D?line=4'>5</a>     models,
#       <a href='vscode-notebook-cell:/c%3A/Users/Phili/Desktop/IntelligenteSysteme/ai_for_smart_health/ai_smart_health_08_accelerometer_data_template.ipynb#X60sZmlsZQ%3D%3D?line=5'>6</a>     nr_epochs=4,
#       <a href='vscode-notebook-cell:/c%3A/Users/Phili/Desktop/IntelligenteSysteme/ai_for_smart_health/ai_smart_health_08_accelerometer_data_template.ipynb#X60sZmlsZQ%3D%3D?line=6'>7</a>     subset_size=1000, #normalerweise hoeher, nur zum testen. Aktuell overfitting
#       <a href='vscode-notebook-cell:/c%3A/Users/Phili/Desktop/IntelligenteSysteme/ai_for_smart_health/ai_smart_health_08_accelerometer_data_template.ipynb#X60sZmlsZQ%3D%3D?line=7'>8</a>     early_stopping_patience=2,
#       <a href='vscode-notebook-cell:/c%3A/Users/Phili/Desktop/IntelligenteSysteme/ai_for_smart_health/ai_smart_health_08_accelerometer_data_template.ipynb#X60sZmlsZQ%3D%3D?line=8'>9</a>     verbose=True,
#      <a href='vscode-notebook-cell:/c%3A/Users/Phili/Desktop/IntelligenteSysteme/ai_for_smart_health/ai_smart_health_08_accelerometer_data_template.ipynb#X60sZmlsZQ%3D%3D?line=9'>10</a>     outputfile=outputfile,
#      <a href='vscode-notebook-cell:/c%3A/Users/Phili/Desktop/IntelligenteSysteme/ai_for_smart_health/ai_smart_health_08_accelerometer_data_template.ipynb#X60sZmlsZQ%3D%3D?line=10'>11</a>     metric=metric)
#      <a href='vscode-notebook-cell:/c%3A/Users/Phili/Desktop/IntelligenteSysteme/ai_for_smart_health/ai_smart_health_08_accelerometer_data_template.ipynb#X60sZmlsZQ%3D%3D?line=11'>12</a> print('Details of the training process were stored in ',outputfile)
#
# File c:\Users\Phili\anaconda3\envs\chatbots\lib\site-packages\mcfly\find_architecture.py:177, in train_models_on_samples(X_train, y_train, X_val, y_val, models, nr_epochs, subset_size, verbose, outputfile, model_path, early_stopping_patience, batch_size, metric, class_weight)
#     175 else:
#     176     callbacks = []
# --> 177 history = model.fit(x = data_train,
#     178                     epochs=nr_epochs,
#     179                     # see comment on subsize_set
#     180                     validation_data=data_val,
#     181                     verbose=verbose,
#     182                     callbacks=callbacks,
#     183                     class_weight=class_weight)
#     184 histories.append(history)
#     186 for metric_name in model.metrics_names:
#
# File c:\Users\Phili\anaconda3\envs\chatbots\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Phili\anaconda3\envs\chatbots\lib\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:880, in Function.__call__(self, *args, **kwds)
#     877 compiler = "xla" if self._jit_compile else "nonXla"
#     879 with OptionalXlaContext(self._jit_compile):
# --> 880   result = self._call(*args, **kwds)
#     882 new_tracing_count = self.experimental_get_tracing_count()
#     883 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:912, in Function._call(self, *args, **kwds)
#     909   self._lock.release()
#     910   # In this case we have created variables on the first call, so we run the
#     911   # defunned version which is guaranteed to never create variables.
# --> 912   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913 elif self._variable_creation_fn is not None:
#     914   # Release the lock early so that multiple threads can perform the call
#     915   # in parallel.
#     916   self._lock.release()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:134, in TracingCompiler.__call__(self, *args, **kwargs)
#     131 with self._lock:
#     132   (concrete_function,
#     133    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134 return concrete_function._call_flat(
#     135     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1745, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1741 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1742 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1743     and executing_eagerly):
#    1744   # No tape is watching; skip to running the function.
# -> 1745   return self._build_call_outputs(self._inference_function.call(
#    1746       ctx, args, cancellation_manager=cancellation_manager))
#    1747 forward_backward = self._select_forward_and_backward_functions(
#    1748     args,
#    1749     possible_gradient_type,
#    1750     executing_eagerly)
#    1751 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:378, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     376 with _InterpolateFunctionError(self):
#     377   if cancellation_manager is None:
# --> 378     outputs = execute.execute(
#     379         str(self.signature.name),
#     380         num_outputs=self._num_outputs,
#     381         inputs=args,
#     382         attrs=attrs,
#     383         ctx=ctx)
#     384   else:
#     385     outputs = execute.execute_with_cancellation(
#     386         str(self.signature.name),
#     387         num_outputs=self._num_outputs,
#    (...)
#     390         ctx=ctx,
#     391         cancellation_manager=cancellation_manager)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %%
models
# Out:
# [(<keras.engine.functional.Functional at 0x1d3a31124c0>,
#   {'learning_rate': 0.004741712758572711,
#    'regularization_rate': 0.0030760874784206507,
#    'network_depth': 6,
#    'filters_number': 62,
#    'max_kernel_size': 87},
#   'InceptionTime'),
#  (<keras.engine.functional.Functional at 0x1d3a31c3610>,
#   {'learning_rate': 0.0019013957308651832,
#    'regularization_rate': 0.006579609441735624,
#    'network_depth': 6,
#    'filters_number': 52,
#    'max_kernel_size': 32},
#   'InceptionTime'),
#  (<keras.engine.functional.Functional at 0x1d3a3219700>,
#   {'learning_rate': 0.0006523858178152041,
#    'regularization_rate': 0.00856523165407815,
#    'network_depth': 6,
#    'filters_number': 59,
#    'max_kernel_size': 10},
#   'InceptionTime')]

# %%
from mcfly.models.inception_time import InceptionTime
inception = InceptionTime(x_shape=(None,512,9),number_of_classes=7)

model =inception.create_model(filters_number=55, network_depth=4, max_kernel_size=30, learning_rate=0.003,regularization_rate=0.08)
# Out:
# c:\Users\Phili\anaconda3\envs\chatbots\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
model.summary()
# Out:
# Model: "model_15"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_16 (InputLayer)          [(None, 512, 9)]     0           []
#
#  batch_normalization_124 (Batch  (None, 512, 9)      36          ['input_16[0][0]']
#  Normalization)
#
#  conv1d_374 (Conv1D)            (None, 512, 32)      288         ['batch_normalization_124[0][0]']
#
#  max_pooling1d_68 (MaxPooling1D  (None, 512, 9)      0           ['batch_normalization_124[0][0]']
#  )
#
#  conv1d_375 (Conv1D)            (None, 512, 55)      52800       ['conv1d_374[0][0]']
#
#  conv1d_376 (Conv1D)            (None, 512, 55)      26400       ['conv1d_374[0][0]']
#
#  conv1d_377 (Conv1D)            (None, 512, 55)      12320       ['conv1d_374[0][0]']
#
#  conv1d_378 (Conv1D)            (None, 512, 55)      495         ['max_pooling1d_68[0][0]']
#
#  concatenate_68 (Concatenate)   (None, 512, 220)     0           ['conv1d_375[0][0]',
#                                                                   'conv1d_376[0][0]',
#                                                                   'conv1d_377[0][0]',
#                                                                   'conv1d_378[0][0]']
#
#  batch_normalization_125 (Batch  (None, 512, 220)    880         ['concatenate_68[0][0]']
#  Normalization)
#
#  activation_118 (Activation)    (None, 512, 220)     0           ['batch_normalization_125[0][0]']
#
#  conv1d_379 (Conv1D)            (None, 512, 32)      7040        ['activation_118[0][0]']
#
#  max_pooling1d_69 (MaxPooling1D  (None, 512, 220)    0           ['activation_118[0][0]']
#  )
#
#  conv1d_380 (Conv1D)            (None, 512, 55)      52800       ['conv1d_379[0][0]']
#
#  conv1d_381 (Conv1D)            (None, 512, 55)      26400       ['conv1d_379[0][0]']
#
#  conv1d_382 (Conv1D)            (None, 512, 55)      12320       ['conv1d_379[0][0]']
#
#  conv1d_383 (Conv1D)            (None, 512, 55)      12100       ['max_pooling1d_69[0][0]']
#
#  concatenate_69 (Concatenate)   (None, 512, 220)     0           ['conv1d_380[0][0]',
#                                                                   'conv1d_381[0][0]',
#                                                                   'conv1d_382[0][0]',
#                                                                   'conv1d_383[0][0]']
#
#  batch_normalization_126 (Batch  (None, 512, 220)    880         ['concatenate_69[0][0]']
#  Normalization)
#
#  activation_119 (Activation)    (None, 512, 220)     0           ['batch_normalization_126[0][0]']
#
#  conv1d_384 (Conv1D)            (None, 512, 32)      7040        ['activation_119[0][0]']
#
#  max_pooling1d_70 (MaxPooling1D  (None, 512, 220)    0           ['activation_119[0][0]']
#  )
#
#  conv1d_385 (Conv1D)            (None, 512, 55)      52800       ['conv1d_384[0][0]']
#
#  conv1d_386 (Conv1D)            (None, 512, 55)      26400       ['conv1d_384[0][0]']
#
#  conv1d_387 (Conv1D)            (None, 512, 55)      12320       ['conv1d_384[0][0]']
#
#  conv1d_388 (Conv1D)            (None, 512, 55)      12100       ['max_pooling1d_70[0][0]']
#
#  concatenate_70 (Concatenate)   (None, 512, 220)     0           ['conv1d_385[0][0]',
#                                                                   'conv1d_386[0][0]',
#                                                                   'conv1d_387[0][0]',
#                                                                   'conv1d_388[0][0]']
#
#  conv1d_389 (Conv1D)            (None, 512, 220)     1980        ['batch_normalization_124[0][0]']
#
#  batch_normalization_127 (Batch  (None, 512, 220)    880         ['concatenate_70[0][0]']
#  Normalization)
#
#  batch_normalization_128 (Batch  (None, 512, 220)    880         ['conv1d_389[0][0]']
#  Normalization)
#
#  activation_120 (Activation)    (None, 512, 220)     0           ['batch_normalization_127[0][0]']
#
#  add_21 (Add)                   (None, 512, 220)     0           ['batch_normalization_128[0][0]',
#                                                                   'activation_120[0][0]']
#
#  activation_121 (Activation)    (None, 512, 220)     0           ['add_21[0][0]']
#
#  conv1d_390 (Conv1D)            (None, 512, 32)      7040        ['activation_121[0][0]']
#
#  max_pooling1d_71 (MaxPooling1D  (None, 512, 220)    0           ['activation_121[0][0]']
#  )
#
#  conv1d_391 (Conv1D)            (None, 512, 55)      52800       ['conv1d_390[0][0]']
#
#  conv1d_392 (Conv1D)            (None, 512, 55)      26400       ['conv1d_390[0][0]']
#
#  conv1d_393 (Conv1D)            (None, 512, 55)      12320       ['conv1d_390[0][0]']
#
#  conv1d_394 (Conv1D)            (None, 512, 55)      12100       ['max_pooling1d_71[0][0]']
#
#  concatenate_71 (Concatenate)   (None, 512, 220)     0           ['conv1d_391[0][0]',
#                                                                   'conv1d_392[0][0]',
#                                                                   'conv1d_393[0][0]',
#                                                                   'conv1d_394[0][0]']
#
#  batch_normalization_129 (Batch  (None, 512, 220)    880         ['concatenate_71[0][0]']
#  Normalization)
#
#  activation_122 (Activation)    (None, 512, 220)     0           ['batch_normalization_129[0][0]']
#
#  global_average_pooling1d_15 (G  (None, 220)         0           ['activation_122[0][0]']
#  lobalAveragePooling1D)
#
#  dense_18 (Dense)               (None, 7)            1547        ['global_average_pooling1d_15[0][
#                                                                  0]']
#
#  activation_123 (Activation)    (None, 7)            0           ['dense_18[0][0]']
#
# ==================================================================================================
# Total params: 432,246
# Trainable params: 430,028
# Non-trainable params: 2,218
# __________________________________________________________________________________________________

# %%
model.fit(X_train, y_train_binary, epochs=1, validation_data=(X_val, y_val_binary))
# Out:
# 357/357 [==============================] - 468s 1s/step - loss: 0.1964 - accuracy: 0.9357 - val_loss: 0.1223 - val_accuracy: 0.9400

# %% [markdown]
# # Choose the best model
# Now that we found an effective architecture, we can choose the most promising model. For example, we can choose the model with the highest accuracy on the validation data set. To maximize this models performance, we will train this model on more data and more epochs.

# %%
best_model_index = np.argmax(val_accuracies)
best_model, best_params, best_model_types = models[best_model_index]
print('Model type and parameters of the best model:')
print(best_model_types)
print(best_params)

# %% [markdown]
# ## Train the best model on the full dataset

# %% [markdown]
# Now that we have identified the best model architecture out of our random pool of models we can continue by training the model on the full training set.
#
# This would take some time, so instead we will train  on only a slightly larger subset.

# %%
# Continue training? Or train new model?

# %% [markdown]
# ### Saving, loading and comparing reloaded model with original model

# %% [markdown]
# The model can be saved for future use. The savemodel function will save two separate files: a json file for the architecture and a npy (numpy array) file for the weights.

# %% [markdown]
# ## Investigate model predictions

# %% [markdown]
# We will now dive further into the Neural network that we created.
# We provide here a network that has been trained on the complete train set.

# %% [markdown]
# Note that the objects `models`, `best_model_fullytrained` and `best_model` that resulted from the mcfly functions are Keras objects. This means that you can use Keras functions on the objects, for example  `.predict`, (which when given the data, outputs the predictions for each sample) and `.evaluate` (which when given the data and the labels computes how well this model performs) . These functions are all documented in the [Keras documentation](https://www.tensorflow.org/api_docs/python/tf/keras).

# %%
## Inspect model predictions on validation data
datasize = X_val.shape[0]
probs = model.predict(X_val, batch_size=1)
# Out:
# 100/100 [==============================] - 2s 16ms/step

# %% [markdown]
# Let's have a look at the [confusion matrix](https://en.wikipedia.org/wiki/Confusion_matrix)

# %%
#columns are predicted, rows are truth
predicted = probs.argmax(axis=1)
y_index = y_val_binary.argmax(axis=1)
confusion_matrix = pd.crosstab(pd.Series(y_index), pd.Series(predicted))
confusion_matrix.index = [f"{labels[i]} (predicted)" for i in confusion_matrix.index]
confusion_matrix.columns = [labels[i] for i in confusion_matrix.columns]
confusion_matrix.reindex(columns=[l for l in labels], fill_value=0)
confusion_matrix
# Out:
#                               lying  sitting  standing  walking  cycling  \
# lying (predicted)                13        0         0        0        0
# sitting (predicted)               0       11         2        0        1
# standing (predicted)              0        0        20        0        0
# walking (predicted)               0        0         0       15        0
# cycling (predicted)               0        0         0        0       12
# vaccuum_cleaning (predicted)      0        0         0        0        0
# ironing (predicted)               0        1         0        0        0
#
#                               vaccuum_cleaning  ironing
# lying (predicted)                            0        0
# sitting (predicted)                          0        0
# standing (predicted)                         0        0
# walking (predicted)                          0        0
# cycling (predicted)                          0        0
# vaccuum_cleaning (predicted)                 8        0
# ironing (predicted)                          2       15

# %%
## Test on Testset
score_test = model.evaluate(X_test, y_test_binary, verbose=True)
print('Score of best model: ' + str(score_test))
# Out:
# 32/32 [==============================] - 7s 213ms/step - loss: 0.1730 - accuracy: 0.9400
# Score of best model: [0.17303594946861267, 0.9399999976158142]

# %%
model.save("my_model.keras") #als keras format, beinhaltet alle infos und das model
